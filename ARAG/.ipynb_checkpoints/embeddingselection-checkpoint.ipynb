# %%
from llama_index.core import Document
from llama_index.core import StorageContext, load_index_from_storage
from llama_index.core.embeddings import resolve_embed_model
from llama_index.core import VectorStoreIndex, ServiceContext
from sentence_transformers import SentenceTransformer
# 假设你的嵌入模型权重也在本地
from llama_index.core import SimpleDirectoryReader 

documents = SimpleDirectoryReader("./pdf/selectiondata").load_data()

from llama_index.core.node_parser import SimpleNodeParser
from llama_index.core.schema import IndexNode
 
#创建文档切割器
node_parser = SimpleNodeParser.from_defaults(chunk_size=1024)
node_parser

base_nodes = node_parser.get_nodes_from_documents(documents)
len(base_nodes)


embedding_model_path = "local:./embedding/m3e-base"
service_context = ServiceContext.from_defaults(llm=None, embed_model=embed_model)
index = VectorStoreIndex(base_nodes, service_context=service_context) 

rt = index.as_retriever(similarity_top_k=10)
retrievals = rt.retrieve(
    "人类属于动物王国——更明确地说就是属于灵长类这一目；和人类一起同属于灵长类的还有鼯鼱、狐猴,眼镜猴、猴子及类人猿。")

from llama_index.core.response.notebook_utils import display_source_node
 
for n in retrievals:
    display_source_node(n, source_length=1500)
# Out:
# /tmp/ipykernel_3244/1029901346.py:23: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=None, embed_model=embed_model)
# LLM is explicitly disabled. Using MockLLM.
# **Node ID:** 2fb7c3d0-0fe8-4362-b5e9-12ad3c590bec<br>**Similarity:** 0.9058025871565123<br>**Text:** 几乎所有的科学家都认同这种说法：人类属于动物王国
# ——
# 更明确地说
# 就是属于灵长类这一目；和人类一起同属于灵长类的还有鼯鼱、狐猴、
# 眼镜猴、猴子及类人猿。好几个研究领域的成果都为这一说法提供了大
# 量证据。解剖学家发现，从总体来看，人类与其他高级动物在骨骼、肌
# 肉和器官构造方面有不少相似之处。胚胎学家注意到，人类的胚眙在不
# 同的生长阶段，显示出某些低等生物的特征，如：胚胎一个月时有半圆
# 形的鳃，两个月时出现发育不全的尾巴。人类学家指出，人类化石连续
# 地显示出人类由普通的类人猿逐步进化的过程。此外其他科学家也发现
# 了许多能够表明人类与其他动物之间联系的类似迹象，如：猿类血液的
# 化学成分和人类的极其相似，猿类和人类身上有共同的寄生物，而且猿<br>
# **Node ID:** e0c7d66e-3064-4530-b311-ff186bdcb0e1<br>**Similarity:** 0.8672693463820704<br>**Text:** 人类作为自然界众多生命奇迹中的一员，确切地被归类于广阔的动物王国之中，而在这个生命体系的精细划分下，我们归属于哺乳动物类别，更具体地被界定在灵长目这一进化分支。灵长目，这一群体以其高度发展的大脑、独特的手指灵活性和复杂的社会结构，在生物多样性中占据着尤为显著的位置。
#
# 值得注意的是，先前信息中提到的鼯鼱实际上并不属于灵长目，而是一种归属在翼手目中的动物，它们以其轻盈的身躯和皮膜能在树木间滑翔而闻名。因此，准确地说，与人类一同在灵长目下共存的，是一系列其他迷人的生物，包括但不限于：
#
# 1. **狐猴**：这些主要分布在非洲马达加斯加岛上的独特物种，展示了岛屿隔离环境下生物多样性的丰富性，从微小的鼠狐猴到拥有艳丽毛发的环尾狐猴，它们各自适应着岛屿上多样的生态环境。
#
# 2. **眼镜猴**：这些小型夜行性动物以其超乎寻常的大眼睛而著称，这使它们能够在昏暗的环境中精准捕食。眼镜猴分布在东南亚的一些地区，是灵长目中体型较小但适应性极强的代表。
#
# 3. **猴子**：这一类别包含了许多人们熟悉和喜爱的物种，从活泼的猕猴到拥有鲜艳色彩的狨猴，它们广泛分布于世界各地，从热带雨林到干燥的草原，展现了丰富的生态适应策略。
#
# 4. **类人猿**：这部分成员与人类的亲缘关系尤为接近，包括大猩猩、黑猩猩、猩猩和长臂猿等，它们在行为习惯、社会结构甚至某些认知能力上与人类表现出惊人的相似性，为研究人类的起源和进化提供了宝贵的线索。
#
# 这些灵长目动物，每一种都以其独特的生存策略、生态角色和生物特征，共同构建了一个多姿多彩的生物世界。人类作为灵长目大家族中的一员，与其他成员共享着生命的奥秘，同时也提醒我们保护这些珍贵的生物多样性，维护地球生态系统的健康与和谐。<br>
# **Node ID:** 4012fb5b-dd25-4d9e-9d66-e5a59483f4d1<br>**Similarity:** 0.851200985381511<br>**Text:** 在生命的宏伟殿堂中，人类被精准地归类于庞大的动物界，此界涵盖了地球上形态各异、生态多样的无数生物种类。更细致地划分，人类归属于哺乳动物门，进而归入灵长目这一分支。灵长目，一个集合了智慧、敏捷与高度社会性的生物群体，不仅是我们人类的归属之地，也是许多其他令人着迷物种的家园。
#
# 在这个多样化的灵长目家族中，鼯猴其实是一个误解，因为鼯猴并非灵长目成员，它们实际上是属于翼手目的动物，以其独特的滑翔能力穿梭于林间。而真正与人类共享灵长目分类的，是诸如狐猴——马达加斯加岛上特有的一系列物种，它们以其多样的生态位和生存策略，成为了生物多样性研究中的亮点；眼镜猴，这些小小的生命体拥有不成比例的大眼睛，适应了夜间的丛林生活，展现着自然选择的奥秘；以及多种猴子，从活泼好动的猕猴到拥有鲜艳色彩的狨猴，它们以各自特有的习性和生态角色，装点着地球的每一个角落。
#
# 特别值得一提的是类人猿，包括大猩猩、黑猩猩、猩猩和长臂猿等，它们与人类在遗传学、解剖结构、行为模式乃至情感表达上都有着惊人的相似之处，成为了探索人类起源、演化历程以及理解智能与社会复杂性的重要窗口。这些灵长目家族的成员们，不仅是自然界中不可或缺的一部分，也深刻地反映了生命演化进程中的共通性和多样性，提醒我们保护这一珍贵遗产，维护地球生态系统的健康与平衡。<br>
# **Node ID:** 3d555b5f-2c66-44dc-a2fe-4de282fc7a6c<br>**Similarity:** 0.8440365516835695<br>**Text:** 在精密的生物学分类体系中，人类被严谨地定位在宏大的动物界范畴内，更进一步地，我们归属于哺乳动物门下的灵长目这一分支。灵长目，一个汇聚了高智能、高度适应性和复杂社群生活的生物类群，不仅是人类的分类归属，也是一个生态多样性异常丰富的家族，其中包括了一系列引人入胜的物种。
#
# 在这里，需要纠正的是鼯猴并非灵长目成员，它实际上属于翼手目，以其独特的滑翔膜在林间自由翱翔。而在真正的灵长目大家庭里，树栖的狐猴显得格外引人注目，它们作为马达加斯加独有的物种，展现了生态隔离下生物多样性的奇迹，不同的狐猴种类在岛上形成了独特的生态位。小巧的眼镜猴，以其超乎寻常的大眼睛和夜间活动习性，成为了夜幕下森林的精灵，揭示了自然选择对特定环境适应的精妙设计。
#
# 此外，各式各样的猴子，从热带雨林的喧闹长尾猴到干旱草原上的狒狒，它们在不同的生境中繁衍生息，展现了灵长目动物广泛的地理分布和生态适应性。特别是与人类共享诸多特性的类人猿，包括黑猩猩、大猩猩、猩猩和长臂猿等，它们在基因组、身体构造、行为习惯乃至情感表达上与人类有着惊人的相似之处，成为科学家探索人类进化历史、社会行为和认知能力的关键模型。
#
# 综上所述，灵长目这一分支不仅体现了人类与其他灵长类动物之间的密切联系，还凸显了大自然在进化过程中创造的多样化生命形式。每一物种都承载着独特的生态功能，共同维系着地球生态系统的平衡与稳定，强调了生物多样性保护的重要性。<br>
# **Node ID:** d7c27b56-46d7-4fe2-a727-bd8220022456<br>**Similarity:** 0.842476529363956<br>**Text:** 人类，作为生物多样性中独特而复杂的一环，归属于广阔的动物王国之中，这个王国包含了数百万种形态各异、生态多样的物种。在这一宏伟的生命体系内，人类被精准地分类至哺乳纲，进一步细分为灵长目。灵长目动物，以其高度发达的大脑、灵活的手指和复杂的社交行为著称，构成了一个极为丰富多彩的生物类群。
#
# 与人类共享灵长目分类的，不仅仅是我们熟知的近亲，如各种猴子和类人猿（包括大猩猩、黑猩猩、猩猩及长臂猿等），还包括了一些可能不那么广为人知但同样迷人的物种，比如鼯鼱——实际上这里可能有一个小误会，因为鼯鼱属于翼手目而非灵长目，它们是以滑翔能力著称的小型哺乳动物。正确的灵长类“家族成员”应包括懒猴、狐猴和眼镜猴等，这些动物各自拥有独特的适应性和生存策略。
#
# 狐猴，马达加斯加的特有居民，展示了进化的奇妙之处，从拇指缺失的鼠狐猴到拥有美丽环状尾巴的环尾狐猴，形态各异。眼镜猴，则以其超大的眼睛和夜行性生活方式引人注目，是地球上最小的灵长类之一。而诸如黑猩猩和大猩猩之类的类人猿，不仅在外形上与人类有着惊人的相似之处，更在认知能力、情感表达和社会结构上与我们有着深刻的共鸣，为研究人类的起源和发展提供了宝贵的线索。
#
# 综上所述，人类作为灵长目家族的一员，与众多其他灵长类动物共同谱写着地球生命史上的精彩篇章，每一物种都在其生态系统中扮演着不可替代的角色，共同维护着生物多样性的平衡与繁荣<br>
# **Node ID:** 72360c26-ff6c-46fb-99c2-c7f8d157bc89<br>**Similarity:** 0.8345933959079141<br>**Text:** 在自然界那浩瀚无垠的生命图谱里，人类被精确地定位在广阔的动物界领域内，隶属于哺乳纲下的灵长目类别。灵长目，这一分支汇集了智力超群、生理结构精妙且社会行为复杂的生物群体，人类自豪地置身其中，与一系列非凡的物种共享这一分类地位。
#
# 我们的灵长目亲戚圈内，不仅拥抱了智慧与形态上与我们紧密相连的猴子和类人猿族群——包括但不限于机敏的大猩猩、黑猩猩、猩猩和长臂猿，还涵盖了众多独特而神秘的种类，例如生活在遥远马达加斯加岛上的狐猴，它们以多样化的生态习性和适应策略，展现了自然选择的奇迹。另外，提及的眼镜猴，以其特大号的眼睛和卓越的夜间生活方式，在灵长目家族中独树一帜，而实际上鼯鼱并非灵长目成员，它们凭借滑翔技能在翼手目中占有一席之地。
#
# 从拥有迷人环尾的环尾狐猴，到那些在认知智能、情感交流和社会组织结构上与人类展现出惊人相似性的类人猿，每一种灵长类动物都是自然界中不可或缺的瑰宝，它们以各自的生存之道丰富着地球的生态多样性。人类作为这一大家庭中的一员，与所有灵长类亲属一道，共同编织着地球生物史上错综复杂而又绚烂多彩的篇章，提醒着我们每一个生命体对于维持生态平衡和促进生物多样性的重要性。<br>
# **Node ID:** f8c1d008-7caa-4238-9ea1-b7e4314db444<br>**Similarity:** 0.8171731946503621<br>**Text:** 至此人类的足迹已经遍布除南极洲之外的所有大陆，从而和狗一
# 样成了世界上分布最广的动物
# (
# 见地图
# 1)
# 。
# 在人类向各地迁徙的同时，也逐步开始有了种族上的差别，出现了各种
# 在肤色、发型和面型上各有显著特点的所谓的种族。般认为，这些种族
# 的形成主要是由于人类的各个地域集团适应了其各自不同的环境，而且
# 相互隔绝。关于人种差别，有一点很重要，这就是人种分野发生得很
# 晚
# …
# 在完全意义上的人类形成之后。因此，现代的各个种族都源自人类
# 特征十分明显的同一祖先。这就解释了为什么欧洲人能与他们所发现的
# 所有地区的各个种族通婚；也解释了为什么人类现存的各个种族在天生
# 的智力方面并没有很大差别
# ——
# 这一点实际上已经得到了所有人类学者<br>
# **Node ID:** a24b73f5-8e05-4040-bf2b-71e41cf97995<br>**Similarity:** 0.8153406038606551<br>**Text:** 因此尽管更新世灵长类动物的工具很是简单，但它们却依然能
# 够享用到丰盛的食物，包括蛋、蟹、龟、鸟、啮齿动物，还有小羚羊。
# 小羚羊很容易捕猎到，因为它们一遇危险便伏在草丛中一动不动。
# 更新世灵长类动物在非洲平原上漫游了
# 200
# 多万年，在此期间这个种类
# 中先后有好几个物种都经历了产生、兴旰、最后又消亡的过程。由于每
# 年都有许多新的考古发现，而相关的理论又必须随着这些发现而作修
# 正，因此人类学家们尚不能就那
# 200
# 万年中人类物种更迭的细节达成一
# 致。比如说，最近在爪哇出土的人类化石就对传统的
# “
# 非洲起源
# ”
# 理论提
# 出了挑战。该理论认为，最早的人类起源于非洲，然后从这里迁徙到亚
# 洲、欧洲、美洲和大洋洲大陆。爪哇出土的化石古老得惊人，足以支持
# 人类多地域起源论者的观点。该理论认为早期的人类在全世界上的许多
# 地方独立地起源和进化。
# 2
# 毫无疑问，将来每年都会有许多新的人类学
# 考古发现，而随之而来也就会提出更多新的人类学理论米解释新的化石
# 发现。<br>
# **Node ID:** 951aefff-8198-40cb-901d-2d32aeac092b<br>**Similarity:** 0.8115794365796658<br>**Text:** 类和人类学习的方式也很相似。
# 人类祖先的演变发生在有
# 6—7
# 次大冰期和
# 5—6
# 次间冰期的更新世时代。
# 当时急剐的环境变化迫使所有的动物都必须不断地适应和再适应变化着
# 的环境，而能否从残酷的适应过程中脱颖而出，关键不是取决于蛮力，
# 也不取决于耐寒的能力，而是取决于智力的不断增长，取决于能否运用
# 其智力使自己较好地适应环境的需要。当然，这也就是人类之所以能够
# 在地球上居于无可争辩的主宰地位的秘密。而其中首要的也是最重要的
# 一点就是，人类具有多方面的才能。人类与双臂柔软组长、只适应森林
# 生活的长臂猿和有着厚实的白毛皮、只适应北极环境的北极熊不同，它
# 能够利用自己的智力去应对各种环境。
# 人类是自然选择的产物，是从一系列人类的祖先即近似人形的原人进化
# 而来韵。原人中有一部分已经能够使用简单的石制工具和武器。最早出
# 现的原人是更新世灵长类动物，它们一般被认为最早出现在
# 400
# 多万年
# 前非洲东部和南部的热带草原上。这种灵长类动物的骨盆和腿与现代人
# 极为相似，但其脑容量却仅及人类的三分之一，几乎还不及现在类人猿
# 的脑容量大。因此可以说，这种与人相像的两足动物
# (
# 原人不再用四肢
# 行走
# )
# 的运动系统是与猿脑般的大脑结合在一起的。
# 对处于这种发展水平的灵长类来说，非洲大草原是它们的一个非常理想
# 的生存环境。那里气候温和，即使缺衣少物也能生活得很好。而且辽阔
# 的大草原与茂密的森林和荒凉的沙漠不同，那里有水源，也有可供食用
# 的动物。因此尽管更新世灵长类动物的工具很是简单，但它们却依然能
# 够享用到丰盛的食物，包括蛋、蟹、龟、鸟、啮齿动物，还有小羚羊。
# 小羚羊很容易捕猎到，因为它们一遇危险便伏在草丛中一动不动。
# 更新世灵长类动物在非洲平原上漫游了
# 200
# 多万年，在此期间这个种类
# 中先后有好几个物种都经历了产生、兴旰、最后又消亡的过程。<br>
# **Node ID:** f6e50c5a-820b-4bc0-ac58-7e3d2ecfa1ce<br>**Similarity:** 0.7895471739733138<br>**Text:** 食物的地方，和其他动物一样以采集现成食物为生，而不是像他们擅长
# 农耕的后代那样通过种养来获得食物。
# 一、从类人猿到人类
# 我们所在的地球围绕着太阳旋转，太阳只不过是我们银河系中数百万颗
# 恒星中的一颗，而银河系又只是整个宇宙几百万个星系中的一个。当本
# 书在以后的章节中回溯人类的经历和追寻人类的思想足迹时，我们一定
# 要记住这个如此悬殊的对比。比较好记的一个类比就是，地球在宇宙当
# 中小得就像太平洋上的一粒尘埃。
# 地球形成于约
# 50
# 亿年以前，但直到距今约
# 40
# 亿年前地球上才出现最早的
# 生命
# ——
# 原生的单细胞生物。尽管在传统上人们都认为那
# ‘
# 种原始的生
# 命也与非生物有着质的区别，但是现在的科学家们都已经不再接受这种
# 将生物与非生物截然分开的观点，而是把牛物看作由非生物自然进化而
# 来的。他们按照组织的分类等级标准将所有的物质加以分类，在这一组
# 织的某一等级上无机物转变成了有机物。更具体地说就是，电子、质子
# 和中子相互结合形成各种原子，各种原子相互结合组成各种分子，各种
# 分子再组成有机化程度不等的聚合体，其中有一类有机聚合体形成了生
# 物。
# 接着生物又从低等级向高等级不断地进化：先由微生物进化到原始植
# 物，如海藻；继而又进化到无脊椎动物，如水母、蠕虫；最终则进化到
# 脊椎动物。这些脊椎动物和其旁系中的某些无脊椎动物及植物一起，于
# 3
# 亿年前左右成功地适应了陆上生活。最早适应陆地生活的是两栖动
# 物，随后是史前时期的大批爬行动物，接着是鸟类，最后则是哺乳类动
# 物。哺乳类动物在生物界占据统治地位已达
# 6000
# 万年。
# 几乎所有的科学家都认同这种说法：人类属于动物王国
# ——
# 更明确地说
# 就是属于灵长类这一目；和人类一起同属于灵长类的还有鼯鼱、狐猴、
# 眼镜猴、猴子及类人猿。好几个研究领域的成果都为这一说法提供了大
# 量证据。解剖学家发现，从总体来看，人类与其他高级动物在骨骼、肌
# 肉和器官构造方面有不少相似之处。<br>

# %% [raw]
# print(text_list)
